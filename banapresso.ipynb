# %%
import chromedriver_autoinstaller
import time
from selenium import webdriver
from urllib.request import Request, urlopen

# %%
import time

# 매장 이름 데이터 출력
driver = webdriver.Chrome()
url = 'https://banapresso.com/store'
driver.get(url)

storename = []

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[2]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)

pageclick_xpath3 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[3]/a'
driver.find_element('xpath' , pageclick_xpath3).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)

pageclick_xpath4 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[4]/a'
driver.find_element('xpath' , pageclick_xpath4).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)

pageclick_xpath5 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[5]/a'
driver.find_element('xpath' , pageclick_xpath5).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)

pagechange_xpath = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/span[2]/a'
driver.find_element('xpath' , pagechange_xpath).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[2]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)

pageclick_xpath3 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[3]/a'
driver.find_element('xpath' , pageclick_xpath3).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)

pageclick_xpath4 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[4]/a'
driver.find_element('xpath' , pageclick_xpath4).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)

pageclick_xpath5 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[5]/a'
driver.find_element('xpath' , pageclick_xpath5).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)

pagechange_xpath = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/span[2]/a'
driver.find_element('xpath' , pagechange_xpath).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[2]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)

pageclick_xpath3 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[3]/a'
driver.find_element('xpath' , pageclick_xpath3).click()

for i in range(1):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    storename.append(name)


# 매장 주소 데이터 출력
driver = webdriver.Chrome()
url = 'https://banapresso.com/store'
driver.get(url)

storeaddress = []

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/span"
    name = driver.find_element('xpath', storename_xpath).text
    storeaddress.append(name)

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[2]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/span"
    name = driver.find_element('xpath', storename_xpath).text
    storeaddress.append(name)

pageclick_xpath3 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[3]/a'
driver.find_element('xpath' , pageclick_xpath3).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/span"
    name = driver.find_element('xpath', storename_xpath).text
    storeaddress.append(name)

pageclick_xpath4 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[4]/a'
driver.find_element('xpath' , pageclick_xpath4).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/span"
    name = driver.find_element('xpath', storename_xpath).text
    storeaddress.append(name)

pageclick_xpath5 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[5]/a'
driver.find_element('xpath' , pageclick_xpath5).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/span"
    name = driver.find_element('xpath', storename_xpath).text
    storeaddress.append(name)

pagechange_xpath = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/span[2]/a'
driver.find_element('xpath' , pagechange_xpath).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/span"
    name = driver.find_element('xpath', storename_xpath).text
    storeaddress.append(name)

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[2]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/span"
    name = driver.find_element('xpath', storename_xpath).text
    storeaddress.append(name)

pageclick_xpath3 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[3]/a'
driver.find_element('xpath' , pageclick_xpath3).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/span"
    name = driver.find_element('xpath', storename_xpath).text
    storeaddress.append(name)

pageclick_xpath4 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[4]/a'
driver.find_element('xpath' , pageclick_xpath4).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/span"
    name = driver.find_element('xpath', storename_xpath).text
    storeaddress.append(name)

pageclick_xpath5 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[5]/a'
driver.find_element('xpath' , pageclick_xpath5).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/span"
    name = driver.find_element('xpath', storename_xpath).text
    storeaddress.append(name)

pagechange_xpath = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/span[2]/a'
driver.find_element('xpath' , pagechange_xpath).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/span"
    name = driver.find_element('xpath', storename_xpath).text
    storeaddress.append(name)

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[2]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/span"
    name = driver.find_element('xpath', storename_xpath).text
    storeaddress.append(name)

pageclick_xpath3 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[3]/a'
driver.find_element('xpath' , pageclick_xpath3).click()

# %%
import os
import requests

# image_xpath = '/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[1]/a/div/img'
# image_url = driver.find_element('xpath', image_xpath).get_attribute('src')

# 이미지 다운로드
# response = requests.get(image_url)
# with open('downloaded_image.jpg', 'wb') as img_file:
#     img_file.write(response.content)

# # 새로운 파일 이름
# new_image_name = '가산디지털단지.jpg'

# # 파일 이름 변경
# os.rename('downloaded_image.jpg', new_image_name)

driver = webdriver.Chrome()
url = 'https://banapresso.com/store'
driver.get(url)

for i in range(10):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[2]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[3]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[4]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[5]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

pagechange_xpath = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/span[2]/a'
driver.find_element('xpath' , pagechange_xpath).click()

for i in range(10):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[2]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[3]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[4]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[5]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

pagechange_xpath = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/span[2]/a'
driver.find_element('xpath' , pagechange_xpath).click()

for i in range(10):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[2]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(10):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

pageclick_xpath2 = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[3]/a'
driver.find_element('xpath' , pageclick_xpath2).click()

for i in range(1):
    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/div/img'
    image_url = driver.find_element('xpath',image_xpath).get_attribute('src')
    image_byte = Request(image_url, headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})    
    storename_xpath = f"/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{i+1}]/a/span/i"
    name = driver.find_element('xpath', storename_xpath).text
    f = open(f'./images/{name}.jpg', 'wb')
    f.write(urlopen(image_byte).read())
    f.close()

# %%
# !pip install "pymongo[srv]"
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pymongo import MongoClient

# %%
url = 'mongodb+srv://sakongmyoungheun:sXdO2vFDKYn9Vco0@cluster0.73kydp8.mongodb.net/?retryWrites=true&w=majority'
client = MongoClient(url)

database = client['kdt']
collection = database['user']

# %%
for i in range(len(storename)):
    store_insert = {'imagename' : storename[i], 'storename' : storename[i] , 'storeaddress' : storeaddress[i]}
    result = collection.insert_one(store_insert)
    print(store_insert)
    print(f'입력된 데이터 id: {result.inserted_id}' )
    time.sleep(1)
# Out:
# {'imagename': '가산디지털단지역점', 'storename': '가산디지털단지역점', 'storeaddress': '서울시 금천구 가산동 60-3', '_id': ObjectId('65658c4b1ceb0cfd6dfa462c')}
# 입력된 데이터 id: 65658c4b1ceb0cfd6dfa462c
# {'imagename': '가산파트너스타워점', 'storename': '가산파트너스타워점', 'storeaddress': '서울특별시 금천구 가산디지털1로 83, 103호-1', '_id': ObjectId('65658c4c1ceb0cfd6dfa462d')}
# 입력된 데이터 id: 65658c4c1ceb0cfd6dfa462d
# {'imagename': '강남구청점', 'storename': '강남구청점', 'storeaddress': '서울 강남구 청담동 45-4', '_id': ObjectId('65658c4d1ceb0cfd6dfa462e')}
# 입력된 데이터 id: 65658c4d1ceb0cfd6dfa462e
# {'imagename': '강남대로점', 'storename': '강남대로점', 'storeaddress': '서울 서초구 강남대로 359 대우도시의빛2 102호', '_id': ObjectId('65658c4e1ceb0cfd6dfa462f')}
# 입력된 데이터 id: 65658c4e1ceb0cfd6dfa462f
# {'imagename': '강남역사거리점', 'storename': '강남역사거리점', 'storeaddress': '서울특별시 강남구 역삼동 820-10', '_id': ObjectId('65658c4f1ceb0cfd6dfa4630')}
# 입력된 데이터 id: 65658c4f1ceb0cfd6dfa4630
# ...
